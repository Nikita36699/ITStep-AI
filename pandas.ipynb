# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita36699/ITStep-AI/blob/superwised_learning/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Мабуть, найважливішою структурою даних oabdas є `DataFrame`. Це таблична структура, тісно інтегрована з `Series`.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Ми проведемо аналіз країн G7 і зараз розглянемо DataFrames.
#
#
# <img width="700" src="https://user-images.githubusercontent.com/872296/38153492-72c032ca-3443-11e8-80f4-9de9060a5127.png" />
#
# Створення `DataFrame` вручну може бути виснажливим. У 99% випадків ви отримуватимете дані з бази даних, файлу CSV або Інтернету. Але все ж ви можете створити DataFrame, вказавши стовпці та значення:

# %%
df = pd.DataFrame({
    'Name': [
        'Canada',
        'France',
        'Germany',
        'Italy',
        'Japan',
        'United Kingdom',
        'United States',
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.head() #першші 5 рядків
# Out:
#       Name  Population      GDP  Surface Area    HDI Continent  \
# 0   Canada      35.467  1785387     9984670.0  0.913       NaN
# 1   France      63.951  2833687      640679.0  0.888    EUROPE
# 2  Germany      80.940  3874437           NaN  0.916    EUROPE
# 3    Italy      60.665  2167744      301336.0  0.873    EUROPE
# 4    Japan     127.061  4602367      377930.0  0.891      ASIA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406

# %%
df.columns
# Out:
# Index(['Name', 'Population', 'GDP', 'Surface Area', 'HDI', 'Continent',
#        'GDP per Capita', 'GDP Per Capita'],
#       dtype='object')

# %% [markdown]
# `DataFrame` також мають індекси рядків. Як ви можете бачити в «таблиці» вище, pandas автоматично призначила числовий зромтаючий індекс кожному «рядку» в нашому DataFrame.
#
# Стовпці "індексуються" назвами типу `str`

# %%
# df.columns = df.columns.str.lower()

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          7 non-null      object
#  1   Population    7 non-null      float64
#  2   GDP           7 non-null      int64
#  3   Surface Area  7 non-null      int64
#  4   HDI           7 non-null      float64
#  5   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 468.0+ bytes

# %%
df.size
# Out:
# 42

# %%
df.shape
# Out:
# (7, 6)

# %%
df.dtypes
# Out:
# Name             object
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %% [markdown]
# ## Індексування та відбір
# Окремі стовпці в DataFrame можна вибирати за допомогою звичайного індексування. Кожен стовпець представлено як `Series`:

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df['HDI']
# Out:
# 0    0.913
# 1    0.888
# 2    0.916
# 3    0.873
# 4    0.891
# 5    0.907
# 6    0.915
# Name: HDI, dtype: float64

# %%
type(df['Population'])

col_names = ['Population', "Name", 'Population']
df[col_names]

# df[['Population', "Name"]]
# Out:
#    Population            Name  Population
# 0      35.467          Canada      35.467
# 1      63.951          France      63.951
# 2      80.940         Germany      80.940
# 3      60.665           Italy      60.665
# 4     127.061           Japan     127.061
# 5      64.511  United Kingdom      64.511
# 6     318.523   United States     318.523

# %%
# рядок з індексом 3:5
df.iloc[3:5, :]
# Out:
#     Name  Population      GDP  Surface Area    HDI Continent
# 3  Italy      60.665  2167744        301336  0.873    Europe
# 4  Japan     127.061  4602367        377930  0.891      Asia

# %%
# стовпчики з індексами 0, 1, -1
col_inds = [0, 1, -1]
df.iloc[:, col_inds]

df.iloc[:, [0, 1, -1]]

df.iloc[2:3, [4, 2]]
# Out:
#      HDI      GDP
# 2  0.916  3874437

# %% [markdown]
# Кілька стовпців також можна вибрати подібно до `numpy` і `Series`:

# %%
df[['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %% [markdown]
# Для індексування `DataFrame` як матрицю `numpy` можна використовувати метод iloc

# %%
df.iloc[:, 1:2]
# Out:
#    Population
# 0      35.467
# 1      63.951
# 2      80.940
# 3      60.665
# 4     127.061
# 5      64.511
# 6     318.523

# %% [markdown]
# Якщо потрібно вказувати не індекси, а назви стовпців, то використовуємо метод loc

# %%
df.loc[:, ['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %% [markdown]
# ## Умовний вибір (булеві масиви)
#
# Ми бачили умовний вибір, застосований в `numpy`, і він працюватиме таким же чином для `DataFrame`.

# %%
mask = df['Continent'] == 'Europe'
mask
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Continent, dtype: bool

# %%
df[mask]
# Out:
#              Name  Population      GDP  Surface Area    HDI Continent
# 1          France      63.951  2833687        640679  0.888    Europe
# 2         Germany      80.940  3874437        357114  0.916    Europe
# 3           Italy      60.665  2167744        301336  0.873    Europe
# 5  United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df[df['Continent'] == "Europe"]
# Out:
#              Name  Population      GDP  Surface Area    HDI Continent
# 1          France      63.951  2833687        640679  0.888    Europe
# 2         Germany      80.940  3874437        357114  0.916    Europe
# 3           Italy      60.665  2167744        301336  0.873    Europe
# 5  United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
# декілька умов
# європейське з HDI >= 0.9
df[(df['Continent'] == 'Europe') & (df['HDI'] >= 0.9)]
# Out:
#              Name  Population      GDP  Surface Area    HDI Continent
# 2         Germany      80.940  3874437        357114  0.916    Europe
# 5  United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df[(df['Continent'] == 'Europe') | (df['HDI'] >= 0.9)]
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df[~(df['Continent'] == 'EUROPE')]
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
mask = df['Continent'] == 'Europe'  # чи в Європі
mask = ~mask    # не в Європі
df[mask]
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent
# 0         Canada      35.467   1785387       9984670  0.913   America
# 4          Japan     127.061   4602367        377930  0.891      Asia
# 6  United States     318.523  17348075       9525067  0.915   America

# %%
# & -- and
# | -- or
# ~ -- not

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df['Population'] > 70
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Population, dtype: bool

# %%
df[df['Population'] > 70]
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent
# 2        Germany      80.940   3874437        357114  0.916    Europe
# 4          Japan     127.061   4602367        377930  0.891      Asia
# 6  United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# Булева маска дозволяє вибрати потрібні рядки, враховуючи всі стовпчики. Якщо потрібно вибрати лише деякі стовпці, то використовуємо метод `.loc`

# %%
df.loc[df['Population'] > 70, ['Name']]
# Out:
#             Name
# 2        Germany
# 4          Japan
# 6  United States

# %%
df.loc[df['Population'] > 70, ['Name', 'Population', 'GDP']]
# Out:
#             Name  Population       GDP
# 2        Germany      80.940   3874437
# 4          Japan     127.061   4602367
# 6  United States     318.523  17348075

# %% [markdown]
# # Задача з дз

# %%
data = pd.DataFrame({
    "Кіт": [0.50, 0.20, 0.05, 0.10, 0.15, 0.05],
    "Автомобіль": [0.05, 0.05, 0.05, 0.60, 0.05, 0.10],
    "Собака": [0.30, 0.40, 0.05, 0.10, 0.25, 0.05],
    "Автомобіль": [0.05, 0.05, 0.05, 0.60, 0.05, 0.10],
    "Дерево": [0.05, 0.05, 0.05, 0.10, 0.45, 0.75],
    "Птах": [0.10, 0.30, 0.80, 0.10, 0.10, 0.05],
})

data
# Out:
#     Кіт  Автомобіль  Собака  Дерево  Птах
# 0  0.50        0.05    0.30    0.05  0.10
# 1  0.20        0.05    0.40    0.05  0.30
# 2  0.05        0.05    0.05    0.05  0.80
# 3  0.10        0.60    0.10    0.10  0.10
# 4  0.15        0.05    0.25    0.45  0.10
# 5  0.05        0.10    0.05    0.75  0.05

# %%
# (6, 5) -> (6)
data.idxmax(axis=1)
# Out:
# 0           Кіт
# 1        Собака
# 2          Птах
# 3    Автомобіль
# 4        Дерево
# 5        Дерево
# dtype: object

# %%
data['Object'] = data.idxmax(axis=1)

data
# Out:
#     Кіт  Автомобіль  Собака  Дерево  Птах      Object
# 0  0.50        0.05    0.30    0.05  0.10         Кіт
# 1  0.20        0.05    0.40    0.05  0.30      Собака
# 2  0.05        0.05    0.05    0.05  0.80        Птах
# 3  0.10        0.60    0.10    0.10  0.10  Автомобіль
# 4  0.15        0.05    0.25    0.45  0.10      Дерево
# 5  0.05        0.10    0.05    0.75  0.05      Дерево

# %% [markdown]
# ## Видалення
#
# На противагу поняттю відбору є «видалення». Замість того, щоб вказувати, які стовпці ви хочете _вибрати_, ви можете вказати, які з них ви хочете `викинути`:

# %%
df.drop(columns=['Population'], inplace=False)
# Out:
#              Name       GDP  Surface Area    HDI Continent
# 0          Canada   1785387       9984670  0.913   America
# 1          France   2833687        640679  0.888    Europe
# 2         Germany   3874437        357114  0.916    Europe
# 3           Italy   2167744        301336  0.873    Europe
# 4           Japan   4602367        377930  0.891      Asia
# 5  United Kingdom   2950039        242495  0.907    Europe
# 6   United States  17348075       9525067  0.915   America

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis='columns')
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %% [markdown]
# Усі ці методи `drop` повертають новий `DataFrame`. Якщо ви хочете змінити його "на місці", ви можете скористатися атрибутом `inplace`

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## Операції

# %%
df[['Population', 'GDP']]
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
#df['Population'] = df.icol[0, 0]

df['GDP per Capita'] = df['GDP'] / df['Population']

# %%
df['Continent'] = df['Continent'].str.upper()

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   AMERICA
# 1          France      63.951   2833687        640679  0.888    EUROPE
# 2         Germany      80.940   3874437        357114  0.916    EUROPE
# 3           Italy      60.665   2167744        301336  0.873    EUROPE
# 4           Japan     127.061   4602367        377930  0.891      ASIA
# 5  United Kingdom      64.511   2950039        242495  0.907    EUROPE
# 6   United States     318.523  17348075       9525067  0.915   AMERICA
#
#    GDP per Capita
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df['Population'] * 6
# Out:
# 0     212.802
# 1     383.706
# 2     485.640
# 3     363.990
# 4     762.366
# 5     387.066
# 6    1911.138
# Name: Population, dtype: float64

# %%
df['Population'].max()
# Out:
# 318.523

# %% [markdown]
# Аналогічно до `numpy` можна виконувати операції між рядками. Операції виконуються поелементно.

# %%
df['GDP'] / df['Population']
# Out:
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
# dtype: float64

# %% [markdown]
# ## Зміна даних
#
# Це просто та інтуїтивно зрозуміло. Ви можете без проблем додавати стовпці або замінювати значення для стовпців:

# %% [markdown]
# ### Додавання нового стовпця

# %%
df['Language'] = ['English', 'French', 'German', 'Italian', 'Jananese', 'English', 'English']

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   AMERICA
# 1          France      63.951   2833687        640679  0.888    EUROPE
# 2         Germany      80.940   3874437        357114  0.916    EUROPE
# 3           Italy      60.665   2167744        301336  0.873    EUROPE
# 4           Japan     127.061   4602367        377930  0.891      ASIA
# 5  United Kingdom      64.511   2950039        242495  0.907    EUROPE
# 6   United States     318.523  17348075       9525067  0.915   AMERICA
#
#    GDP per Capita  Language
# 0    50339.385908   English
# 1    44310.284437    French
# 2    47868.013343    German
# 3    35733.025633   Italian
# 4    36221.712406  Jananese
# 5    45729.239975   English
# 6    54464.120330   English

# %% [markdown]
# ---
# ### Заміна значень у стовпці

# %%
df['Language'] = 'English'

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   AMERICA
# 1          France      63.951   2833687        640679  0.888    EUROPE
# 2         Germany      80.940   3874437        357114  0.916    EUROPE
# 3           Italy      60.665   2167744        301336  0.873    EUROPE
# 4           Japan     127.061   4602367        377930  0.891      ASIA
# 5  United Kingdom      64.511   2950039        242495  0.907    EUROPE
# 6   United States     318.523  17348075       9525067  0.915   AMERICA
#
#    GDP per Capita Language
# 0    50339.385908  English
# 1    44310.284437  English
# 2    47868.013343  English
# 3    35733.025633  English
# 4    36221.712406  English
# 5    45729.239975  English
# 6    54464.120330  English

# %% [markdown]
# ---
# ### Перейменування стовпців

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'
    })
# Out:
#              Name  Population       GDP  Surface Area  \
# 0          Canada      35.467   1785387       9984670
# 1          France      63.951   2833687        640679
# 2         Germany      80.940   3874437        357114
# 3           Italy      60.665   2167744        301336
# 4           Japan     127.061   4602367        377930
# 5  United Kingdom      64.511   2950039        242495
# 6   United States     318.523  17348075       9525067
#
#    Human Development Index Continent  GDP per Capita Language
# 0                    0.913   AMERICA    50339.385908  English
# 1                    0.888    EUROPE    44310.284437  English
# 2                    0.916    EUROPE    47868.013343  English
# 3                    0.873    EUROPE    35733.025633  English
# 4                    0.891      ASIA    36221.712406  English
# 5                    0.907    EUROPE    45729.239975  English
# 6                    0.915   AMERICA    54464.120330  English

# %% [markdown]
# ---
# ### Видалення стовпців

# %%
df.drop(columns='Language', inplace=True)

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   AMERICA
# 1          France      63.951   2833687        640679  0.888    EUROPE
# 2         Germany      80.940   3874437        357114  0.916    EUROPE
# 3           Italy      60.665   2167744        301336  0.873    EUROPE
# 4           Japan     127.061   4602367        377930  0.891      ASIA
# 5  United Kingdom      64.511   2950039        242495  0.907    EUROPE
# 6   United States     318.523  17348075       9525067  0.915   AMERICA
#
#    GDP per Capita
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df.groupby(by='Continent').count()
# Out:
#            Name  Population  GDP  Surface Area  HDI  GDP per Capita
# Continent
# AMERICA       2           2    2             2    2               2
# ASIA          1           1    1             1    1               1
# EUROPE        4           4    4             4    4               4

# %%
# загальне ввп на континент
df.groupby(by='Continent')['GDP'].sum()
# Out:
# Continent
# AMERICA    19133462
# ASIA        4602367
# EUROPE     11825907
# Name: GDP, dtype: int64

# %% [markdown]
# ---
# ### Зміна індексу

# %%
df.set_index('Name')
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Name
# Canada              35.467   1785387       9984670  0.913   AMERICA
# France              63.951   2833687        640679  0.888    EUROPE
# Germany             80.940   3874437        357114  0.916    EUROPE
# Italy               60.665   2167744        301336  0.873    EUROPE
# Japan              127.061   4602367        377930  0.891      ASIA
# United Kingdom      64.511   2950039        242495  0.907    EUROPE
# United States      318.523  17348075       9525067  0.915   AMERICA
#
#                 GDP per Capita
# Name
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330

# %% [markdown]
# ## Створення стовпців з інших стовпців
#
# Зміна DataFrame часто передбачає поєднання різних стовпців в інші. Наприклад, у нашому аналізі країн ми могли б спробувати обчислити «ВВП на душу населення», що означає просто `GDP / Population`.

# %%
df[['GDP', 'Population']]
# Out:
#         GDP  Population
# 0   1785387      35.467
# 1   2833687      63.951
# 2   3874437      80.940
# 3   2167744      60.665
# 4   4602367     127.061
# 5   2950039      64.511
# 6  17348075     318.523

# %%
df['GDP'] / df['Population']
# Out:
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
# dtype: float64

# %% [markdown]
# Результатом цієї операції є ще одна `Series`, яку ви можете додати до оригінального `DataFrame`:

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   AMERICA
# 1          France      63.951   2833687        640679  0.888    EUROPE
# 2         Germany      80.940   3874437        357114  0.916    EUROPE
# 3           Italy      60.665   2167744        301336  0.873    EUROPE
# 4           Japan     127.061   4602367        377930  0.891      ASIA
# 5  United Kingdom      64.511   2950039        242495  0.907    EUROPE
# 6   United States     318.523  17348075       9525067  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2    47868.013343    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330

# %% [markdown]
# ## Пропущені значення

# %%
for i, j in zip([0, 2, 2, 5], [5, 3, 6, 3]):
  df.iloc[i, j] = np.nan

df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913       NaN
# 1          France      63.951   2833687      640679.0  0.888    EUROPE
# 2         Germany      80.940   3874437           NaN  0.916    EUROPE
# 3           Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4           Japan     127.061   4602367      377930.0  0.891      ASIA
# 5  United Kingdom      64.511   2950039           NaN  0.907    EUROPE
# 6   United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330

# %%
df.dropna(inplace=False)
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent  \
# 1         France      63.951   2833687      640679.0  0.888    EUROPE
# 3          Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4          Japan     127.061   4602367      377930.0  0.891      ASIA
# 6  United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 1    44310.284437    44310.284437
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 6    54464.120330    54464.120330

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913       NaN
# 1          France      63.951   2833687      640679.0  0.888    EUROPE
# 2         Germany      80.940   3874437           NaN  0.916    EUROPE
# 3           Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4           Japan     127.061   4602367      377930.0  0.891      ASIA
# 5  United Kingdom      64.511   2950039           NaN  0.907    EUROPE
# 6   United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330

# %% [markdown]
# Метод `.info` дозволяє дізнатись кількість непропущених значень(non-null count) у кожному стовпчику.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            7 non-null      object
#  1   Population      7 non-null      float64
#  2   GDP             7 non-null      int64
#  3   Surface Area    5 non-null      float64
#  4   HDI             7 non-null      float64
#  5   Continent       6 non-null      object
#  6   GDP per Capita  6 non-null      float64
#  7   GDP Per Capita  7 non-null      float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 580.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name              0
# Population        0
# GDP               0
# Surface Area      2
# HDI               0
# Continent         1
# GDP per Capita    1
# GDP Per Capita    0
# dtype: int64

# %%
df['Continent'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Continent']
# Out:
# 0        NaN
# 1     EUROPE
# 2     EUROPE
# 3     EUROPE
# 4       ASIA
# 5     EUROPE
# 6    AMERICA
# Name: Continent, dtype: object

# %%
df.isnull().sum()
# Out:
# Name              0
# Population        0
# GDP               0
# Surface Area      2
# HDI               0
# Continent         1
# GDP per Capita    1
# GDP Per Capita    0
# dtype: int64

# %%
df.drop(columns=['Surface Area'])
# Out:
#              Name  Population       GDP    HDI Continent  GDP per Capita  \
# 0          Canada      35.467   1785387  0.913       NaN    50339.385908
# 1          France      63.951   2833687  0.888    EUROPE    44310.284437
# 2         Germany      80.940   3874437  0.916    EUROPE             NaN
# 3           Italy      60.665   2167744  0.873    EUROPE    35733.025633
# 4           Japan     127.061   4602367  0.891      ASIA    36221.712406
# 5  United Kingdom      64.511   2950039  0.907    EUROPE    45729.239975
# 6   United States     318.523  17348075  0.915   AMERICA    54464.120330
#
#    GDP Per Capita
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df.isnull().sum()
# Out:
# Name              0
# Population        0
# GDP               0
# Surface Area      2
# HDI               0
# Continent         1
# GDP per Capita    1
# GDP Per Capita    0
# dtype: int64

# %% [markdown]
# Для видалення всіх рядків, які мають хоча б одне пропущене значення можна використати метод `dropna`. Після цього бажано перевірити кількість рядків, що залишились.

# %%
df.dropna()
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent  \
# 1         France      63.951   2833687      640679.0  0.888    EUROPE
# 3          Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4          Japan     127.061   4602367      377930.0  0.891      ASIA
# 6  United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 1    44310.284437    44310.284437
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 6    54464.120330    54464.120330

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913       NaN
# 1          France      63.951   2833687      640679.0  0.888    EUROPE
# 2         Germany      80.940   3874437           NaN  0.916    EUROPE
# 3           Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4           Japan     127.061   4602367      377930.0  0.891      ASIA
# 5  United Kingdom      64.511   2950039           NaN  0.907    EUROPE
# 6   United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330

# %% [markdown]
# Для видалення рядків, які мають пропуск в конкретному стовпці, можна використати логічну маску.

# %%
df[~df['Continent'].isnull()]
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 1          France      63.951   2833687      640679.0  0.888    EUROPE
# 2         Germany      80.940   3874437           NaN  0.916    EUROPE
# 3           Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4           Japan     127.061   4602367      377930.0  0.891      ASIA
# 5  United Kingdom      64.511   2950039           NaN  0.907    EUROPE
# 6   United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330

# %% [markdown]
# ## Збереження
#
# Щоб зберегти `DataFrame` як файл `csv` використовуйте метод `to_csv`

# %%
df.to_csv("g7_data.csv")

# %%
new_df = pd.read_csv('/content/g7_data.csv', index_col='Unnamed: 0')

new_df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913       NaN
# 1          France      63.951   2833687      640679.0  0.888    EUROPE
# 2         Germany      80.940   3874437           NaN  0.916    EUROPE
# 3           Italy      60.665   2167744      301336.0  0.873    EUROPE
# 4           Japan     127.061   4602367      377930.0  0.891      ASIA
# 5  United Kingdom      64.511   2950039           NaN  0.907    EUROPE
# 6   United States     318.523  17348075     9525067.0  0.915   AMERICA
#
#    GDP per Capita  GDP Per Capita
# 0    50339.385908    50339.385908
# 1    44310.284437    44310.284437
# 2             NaN    47868.013343
# 3    35733.025633    35733.025633
# 4    36221.712406    36221.712406
# 5    45729.239975    45729.239975
# 6    54464.120330    54464.120330
